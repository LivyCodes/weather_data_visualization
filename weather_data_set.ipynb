# %%
import pandas as pd

# %%
#loading the weather_data file
weather_data=pd.read_csv("C:\\Users\\Administrator\\Downloads\\weather_data.csv")

# %%
#displaying head portion of the weather_data file
weather_data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#1.Find all records where the weather was exactly clear.
clear_weather=weather_data[weather_data['Weather']=='Clear']
clear_weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#value counts for the weather conditions
weather_conditions=weather_data['Weather'].value_counts()
weather_conditions
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#fetching the column names and their datatypes
weather_data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
#2.Find the number of times the wind speed was exactly 4 km/hr.
wind_speed_4=weather_data[weather_data['Wind Speed_km/h']==4]
wind_speed_4['Wind Speed_km/h'].count()
# Out:
# np.int64(474)

# %%
#3.Check if there are any NULL values present in the dataset.
weather_data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#4.Rename the column "Weather" to "Weather_Condition."
weather_data.rename(columns={'Weather':'Weather_Conditions'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#5.What is the mean visibility of the dataset?
weather_data['Visibility_km'].mean().round(2)
# Out:
# np.float64(27.66)

# %%
#6.Find the number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km.
wind_visibility_check=weather_data[(weather_data['Wind Speed_km/h']>24) &(weather_data['Visibility_km']==25) ]
wind_visibility_check['Visibility_km'].count()
# Out:
# np.int64(308)

# %%
#7.What is the mean value of each column for each weather condition?
weather_data.mean(numeric_only=True)
# Out:
# Temp_C                8.798144
# Dew Point Temp_C      2.555294
# Rel Hum_%            67.431694
# Wind Speed_km/h      14.945469
# Visibility_km        27.664447
# Press_kPa           101.051623
# dtype: float64

# %%
#8.Find all instances where the weather is clear and the relative humidity is greater than 50, or visibility is above 40.
weather_humidity_visibility_check=weather_data[(weather_data['Weather']=='Clear')& ((weather_data['Rel Hum_%']>50)|(weather_data['Visibility_km']>40))]
weather_humidity_visibility_check
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#9.Find the number of weather conditions that include snow.
snowy_weather=weather_data[weather_data['Weather'].str.contains('Snow', case=False)]
snowy_weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# Week 2 DSEA X Lux Academy Projeccy on Exploratory Data Analysis, to uncover interesting patterns, insights, and potential anomalies within the Weather dataset that used for week 1 Assignment.

# %% [markdown]
# 1. Data Overview and Cleaning
# The first step of any data overview and cleaning is preparing your data by ensuring the data is imported correctly, in the right format and the right place. It is then in order to check the attributes of the data using the .shape function and the characteristics of the data i.e the data types and any missing values for each column using the .info() function. Also, it is important to check for any duplicated rows using the .duplicated() function  as part of cleaning. Finally, using the .head() function, look at the first five or any specified number of rows of your dataset.
# In the case that there are any missing values, two actions can be taken.
#     (i) Drop all the missing values using the .dropna(inplace=True) function. The "inplace=True" ensures the original dataframe is updated without making a copy. If we don't include "inplace=True" or if we include "inplace=False", then pandas will revert back to the default.
#     (ii) Fill the missing values using the .fillna() function which iterates through the dataset and fills the miissing values with either the mean, mode, median or any other specified value.
#     It is always advisable to use your own judgement to determine whether to drop or to fill the missing values by looking at the impact the action will have on the dataset.
# As for the duplicated rows, it is advisable to drop them using the .drop_duplicates() function. Duplicates can skew statistical measures and compromise data integrity hence misleading analyses and visualizations.

# %%
#What are the key characteristics of the dataset? (e.g., number of records, features, data types)
print(weather_data.shape)
weather_data.info()
# Out:
# (8784, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#Identify and handle any missing or null values. Describe your approach and reasoning.
#Checking for the null values using the .isnull().sum() function so that i can have the count for each missing record in the dataset.
#Since there are no missing data sets, I can continue with the inspection and manipulation.
weather_data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#Check for and address any duplicate records.
#no duplicates found from running the code below 
weather_data_duplicates=weather_data[weather_data.duplicated()]
weather_data_duplicates
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []

# %% [markdown]
# 2. Statistical Summary
# Statistical summary refers to a set of statistical calculations that characterize the values in a dataset, giving a broader perspective and understanding of a dataset and uncovering relationships between different variables and extracting important variables for the problem at hand.
# The two main types of summary statistics used in evaluation are the measure of central tendency and measure of dispersion.
#     (i) Measures of Central Tendency
#     These are measures that indicate the approximate center of a dataset. The main measures of central tendency are mean, mode and median.
#         -mean: also referred to as the arithmetic average, this  is the sum of all values in a dataset divided by the number of values in the dataset.
#         -mode: this is the most repeated 'element' in a dataset i.e. value with the highest frequency.
#         -median: this is the 'middle most element' in a dataset when arranged in ascending or descending order. If the dataset has an even number of values, the median is the average of the two middle values.
#     (ii) Measures of dispersion
#     These are measures that describe the variability / how spread out the values in a dataset are. The main measures of dispersion are range, variance, standard deviation, interquartile range and mean absolute deviation. The following explain the measures and how to get them in python pandas;
#         -range: this is the difference between the highest and lowest values in a dataset. In python pandas get the range as
#         range=df['column_name1'].max() - df['column_name1'].min()
#         -variance: this is a measure of variability i.e. measure of how far each data point is from the mean in squared units. In python pandas,
#         variance=df['column_name'].var()
#         -standard deviation: this is a measure of how spread out data is around the mean. In python pandas,
#         standard_deviation=df['column_name'].std()
#         -interquartile range: this is a measure of the spread of the middle 50% of the dataset. It's the difference between the 75th and 25th percentiles of the dataset. It eliminates the effect of the outliers. In python pandas,
#         interquartile_range=df['column_name'].Quantile(0.75) - df['column_name'].Quantile(0.25)
#         -mean absolute deviation: this is a measure of the average distance between each data point and the mean of the dataset. In python pandas,
#         mean_absolute_deviation=df['column_name'].mad()
#
# Rather than calculating all the summary statistics individually, another way to do this is by using the .describe() function in python pandas. By using the describe function on a dataframe, it automatically computes basic statistics for all the numerical variables. Any NaN values are automatically skipped in these statistics. Using the  "include='all'", which is optional, in the describe function adds the 'unique', 'top' and 'freq' analyses results on top of the basic statistics results. The top result from "include='all'" is the mode.

# %%
#Provide a statistical summary of the dataset (mean, median, standard deviation, etc.) for numerical features.
weather_data.describe(include='all')
# Out:
#               Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count              8784  8784.000000       8784.000000  8784.000000
# unique             8784          NaN               NaN          NaN
# top     12/31/2012 7:00          NaN               NaN          NaN
# freq                  1          NaN               NaN          NaN
# mean                NaN     8.798144          2.555294    67.431694
# std                 NaN    11.687883         10.883072    16.918881
# min                 NaN   -23.300000        -28.500000    18.000000
# 25%                 NaN     0.100000         -5.900000    56.000000
# 50%                 NaN     9.300000          3.300000    68.000000
# 75%                 NaN    18.800000         11.800000    81.000000
# max                 NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %%
#Identify and describe any significant outliers in the data.
#Temperature Outliers:
temp_iqr = weather_data['Temp_C'].quantile(0.75)-weather_data['Temp_C'].quantile(0.25)
temp_iqr
temp_lower_limit=weather_data['Temp_C'].quantile(0.25)-(1.5*temp_iqr)
temp_lower_limit
temp_upper_limit=weather_data['Temp_C'].quantile(0.75)+(1.5*temp_iqr)
temp_upper_limit
temp_outliers=weather_data[(weather_data['Temp_C']<temp_lower_limit)|(weather_data['Temp_C']>temp_upper_limit)]
print('Temperature Outliers:', temp_outliers['Temp_C'])

#Dew Point Temperature Outliers:
dew_point_temp_iqr = weather_data['Dew Point Temp_C'].quantile(0.75)-weather_data['Dew Point Temp_C'].quantile(0.25)
dew_point_temp_iqr
dew_point_temp_lower_limit=weather_data['Dew Point Temp_C'].quantile(0.25)-(1.5*dew_point_temp_iqr)
dew_point_temp_lower_limit
dew_point_temp_upper_limit=weather_data['Dew Point Temp_C'].quantile(0.75)+(1.5*dew_point_temp_iqr)
dew_point_temp_upper_limit
dew_point_temp_outliers=weather_data[(weather_data['Dew Point Temp_C']<temp_lower_limit)|(weather_data['Dew Point Temp_C']>temp_upper_limit)]
print('Dew Point Temperature Outliers:', dew_point_temp_outliers['Dew Point Temp_C'])

#Relative Humidity Outliers:
rel_hum_iqr = weather_data['Rel Hum_%'].quantile(0.75)-weather_data['Rel Hum_%'].quantile(0.25)
rel_hum_iqr
rel_hum_lower_limit=weather_data['Rel Hum_%'].quantile(0.25)-(1.5*rel_hum_iqr)
rel_hum_lower_limit
rel_hum_upper_limit=weather_data['Rel Hum_%'].quantile(0.75)+(1.5*rel_hum_iqr)
rel_hum_upper_limit
rel_hum_outliers=weather_data[(weather_data['Rel Hum_%']<rel_hum_lower_limit)|(weather_data['Rel Hum_%']>rel_hum_upper_limit)]
print('Relative Humidity Outliers:', rel_hum_outliers['Rel Hum_%'])

#Relative Humidity Outliers:
wind_speed_iqr = weather_data['Wind Speed_km/h'].quantile(0.75)-weather_data['Wind Speed_km/h'].quantile(0.25)
wind_speed_iqr
wind_speed_lower_limit=weather_data['Wind Speed_km/h'].quantile(0.25)-(1.5*wind_speed_iqr)
wind_speed_lower_limit
wind_speed_upper_limit=weather_data['Wind Speed_km/h'].quantile(0.75)+(1.5*wind_speed_iqr)
wind_speed_upper_limit
wind_speed_outliers=weather_data[(weather_data['Wind Speed_km/h']<wind_speed_lower_limit)|(weather_data['Wind Speed_km/h']>wind_speed_upper_limit)]
print('Wind Speed Outliers:', wind_speed_outliers['Wind Speed_km/h'])

#Visibility Outliers:
visibility_iqr = weather_data['Visibility_km'].quantile(0.75)-weather_data['Visibility_km'].quantile(0.25)
visibility_iqr
visibility_lower_limit=weather_data['Visibility_km'].quantile(0.25)-(1.5*visibility_iqr)
visibility_lower_limit
visibility_upper_limit=weather_data['Visibility_km'].quantile(0.75)+(1.5*visibility_iqr)
visibility_upper_limit
visibility_outliers=weather_data[(weather_data['Visibility_km']<visibility_lower_limit)|(weather_data['Visibility_km']>visibility_upper_limit)]
print('Visibility Outliers:', visibility_outliers['Visibility_km'])

#Pressure Outliers:
pressure_iqr = weather_data['Press_kPa'].quantile(0.75)-weather_data['Press_kPa'].quantile(0.25)
pressure_iqr
pressure_lower_limit=weather_data['Press_kPa'].quantile(0.25)-(1.5*pressure_iqr)
pressure_lower_limit
pressure_upper_limit=weather_data['Press_kPa'].quantile(0.75)+(1.5*pressure_iqr)
pressure_upper_limit
pressure_outliers=weather_data[(weather_data['Press_kPa']<pressure_lower_limit)|(weather_data['Press_kPa']>pressure_upper_limit)]
print('Pressure Outliers:', pressure_outliers['Press_kPa'])
# Out:
# Temperature Outliers: Series([], Name: Temp_C, dtype: float64)
# Dew Point Temperature Outliers: 342   -28.5
# 343   -28.0
# 344   -28.5
# Name: Dew Point Temp_C, dtype: float64
# Relative Humidity Outliers: 1984    18
# 3066    18
# Name: Rel Hum_%, dtype: int64
# Wind Speed Outliers: 25      39
# 32      39
# 33      44
# 34      43
# 36      48
#         ..
# 8679    37
# 8680    37
# 8684    37
# 8749    37
# 8750    37
# Name: Wind Speed_km/h, Length: 162, dtype: int64
# Visibility Outliers: 0        8.0
# 1        8.0
# 2        4.0
# 3        4.0
# 4        4.8
#         ...
# 8779     9.7
# 8780     9.7
# 8781     4.8
# 8782     9.7
# 8783    11.3
# Name: Visibility_km, Length: 3539, dtype: float64
# Pressure Outliers: 294     98.94
# 295     98.84
# 296     98.69
# 297     98.56
# 298     98.44
#         ...
# 8553    98.58
# 8554    98.70
# 8555    98.78
# 8556    98.86
# 8557    98.96
# Name: Press_kPa, Length: 207, dtype: float64

# %% [markdown]
# 3. Data Visualization
# Data visualization is the art of graphically/pictorially presenting information and data in order to see trends or patterns and correlations among the data, using visual elements such as charts, graphs and plots, with the aim of making data easier to interpret and understand for better decision making and deriving insights.
# In python, data visualization is made possible through the utilization of libraries such as matplotlib, seaborn, plotly, pandas visualization, altair, bokeh etc. Here's a quick run through some of them:
#     1.Matplotlib
#     Matplotlib is a python library used for creating static, animated and interactive visualizations in python. While Matplotlib is used for basic graph plotting such as line charts, bar graphs, box plots, histograms, scatter plots etc, it works well with data arrays and frames, and is more customizable and pairs well with Pandas and Numpy for Exploratory Data Analysis.
#     To be able to use Matplotlib, the following have to be fulfilled:
#         (i)Installation:
#             Use the command pip install matplotlib
#         (ii)Usage:
#             Ensure you import as follows:
#             import matplotlib.pyplot as plt
#
#     2. Seaborn
#     Seaborn is a data visualization library, built on top of Matplotlib, used for making statistical graphs in python. With fewer commands, Seaborn performs complex visualizations. With more inbuilt themes as compared to Matplotlib, Seaborn is considered more organized and functional and handles the entire dataset as a solitary unit. Seaborn supports plots including but not limited to box plot, scatter plot, regression plot, histogram and more.
#     For use cases, ensure the following are fulfilled:
#         (i)Installation
#             Use the command pip install seaborn
#         (ii)Usage
#             Import as follows:
#             import seaborn as sns
#
#     3.Plotly
#     Plotly is a data visualization python library used for its ability to create interactive plots and dashboards making it easily understandable. Some of plotly's best features are that it has hover tools capabilities that allow detection of outliers or any other anomalies in a large data set, supports a wide range of plots including line charts, scatter plot, bar charts and more, offers endless options for customization and formatting as well as providing the Dash framework for interactive web applications building.
#     Important use cases to fulfill:
#         (i)Installation
#             Use the command:
#             pip install plotly
#         (ii)Usage
#             Import as follows:
#             import plotly.express as px

# %% [markdown]
# a. Box Plots
# A box plot is a graph that shows the minimum(lower extreme), first quartile(25th percentile), median(50th percentile), third quartile(75th percentile) and the maximum(upper extreme) values in a dataset. The data betwen the  first and third quartiles is the interquatile range. The upper and lower extremes are calculated as 1.5 times the inter-quartile range above the 75th percentile, and as 1.5 times the IQR below the 25th percentile. Box plots also display outliers as individual dots that occur beyond the minimum and/or maximum values.

# %%
#Create visualizations to show the distribution of key weather parameters (e.g., temperature, humidity, wind speed).
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib_inline
import plotly.express as px

sns.boxplot( y = weather_data['Temp_C'], data=weather_data)
plt.title('Box Plot of Temperature')
# Out:
# Text(0.5, 1.0, 'Box Plot of Temperature')

# %%
sns.boxplot(y='Dew Point Temp_C', data=weather_data)
plt.title('Box Plot for Dew Point Temp_C')
# Out:
# Text(0.5, 1.0, 'Box Plot for Dew Point Temp_C')

# %%
sns.boxplot(y='Rel Hum_%', data=weather_data)
plt.title('Box Plot for Rel Hum_%')
# Out:
# Text(0.5, 1.0, 'Box Plot for Rel Hum_%')

# %%
sns.boxplot(y='Wind Speed_km/h', data=weather_data)
plt.title('Box Plot for Wind Speed_km/h')
# Out:
# Text(0.5, 1.0, 'Box Plot for Wind Speed_km/h')

# %%
sns.boxplot(y='Visibility_km', data=weather_data)
plt.title('Box Plot for Visibility_km')
# Out:
# Text(0.5, 1.0, 'Box Plot for Visibility_km')

# %%
sns.boxplot(y='Press_kPa', data=weather_data)
plt.title('Box Plot for Press_kPa')
# Out:
# Text(0.5, 1.0, 'Box Plot for Press_kPa')

# %% [markdown]
# b. Scatter Plots
# A scatter plot is a graph that uses dots to represent values for two different numerical variables. Each observation in a scatter plot is represented as a dot. A scatter plot is especially useful if you're looking for correlations. Of the two numerical variables in use, one is a predictor variable, and the other a target variable. A predictor variable is the variable being used to predict an outcome while a target variable is the variable one is trying to predict.
# In a scatter plot, the predictor variable is normally set on the x-axis while the target variable is set on the y-axis.

# %% [markdown]
# c. Histograms
# A histogram is a graph that shows the frequency distribution of numerical data. The y-axis of a histogram represents the frequency while the x-axis varies. A histogram shows the number of observations within each range.

# %%
plt.hist(weather_data['Temp_C'], bins=12, rwidth=0.5, color='pink')
plt.title('The Frequency of Temperature in C ')
plt.xlabel('Temp_C')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
plt.hist(weather_data['Dew Point Temp_C'], bins=5, rwidth=0.5, color='mediumpurple')
plt.title('The Frequency of Dew Point Temperature in C ')
plt.xlabel('Dew Point Temp_C')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
plt.hist(weather_data['Rel Hum_%'], bins=8, rwidth=0.8, color='slateblue')
plt.title('The Frequency of Relative Humidity in % ')
plt.xlabel('Rel Hum_%')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
plt.hist(weather_data['Wind Speed_km/h'], bins=8, rwidth=0.8, color='violet')
plt.title('The Frequency of Wind Speed in km/h ')
plt.xlabel('Wind Speed_km/h')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
plt.hist(weather_data['Visibility_km'], bins=5, rwidth=0.5, color='lightsteelblue')
plt.title('The Frequency of Visibility in km ')
plt.xlabel('Visibility_km')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
plt.hist(weather_data['Press_kPa'], bins=6, rwidth=0.7, color='steelblue')
plt.title('The Frequency of Pressure in kPa')
plt.xlabel('Press_kPa')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
#Plot time series graphs to visualize trends over time. Highlight any notable patterns or seasonal variations.
# Convert 'Date/Time' to datetime format
weather_data['Date/Time'] = pd.to_datetime(weather_data['Date/Time'])

# Set 'Date/Time' as the index
weather_data.set_index('Date/Time', inplace=True)

# Plot time series graphs for key weather parameters
plt.figure(figsize=(14, 10))

# Temperature
plt.subplot(3, 2, 1)
plt.plot(weather_data.index, weather_data['Temp_C'], color='blue', alpha=0.7)
plt.title('Temperature (°C)')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (°C)')
plt.grid(True)

# Dew Point Temperature
plt.subplot(3, 2, 2)
plt.plot(weather_data.index, weather_data['Dew Point Temp_C'], color='green', alpha=0.7)
plt.title('Dew Point Temperature (°C)')
plt.xlabel('Date/Time')
plt.ylabel('Dew Point Temp (°C)')
plt.grid(True)

# Relative Humidity
plt.subplot(3, 2, 3)
plt.plot(weather_data.index, weather_data['Rel Hum_%'], color='orange', alpha=0.7)
plt.title('Relative Humidity (%)')
plt.xlabel('Date/Time')
plt.ylabel('Relative Humidity (%)')
plt.grid(True)

# Wind Speed
plt.subplot(3, 2, 4)
plt.plot(weather_data.index, weather_data['Wind Speed_km/h'], color='red', alpha=0.7)
plt.title('Wind Speed (km/h)')
plt.xlabel('Date/Time')
plt.ylabel('Wind Speed (km/h)')
plt.grid(True)

# Visibility
plt.subplot(3, 2, 5)
plt.plot(weather_data.index, weather_data['Visibility_km'], color='purple', alpha=0.7)
plt.title('Visibility (km)')
plt.xlabel('Date/Time')
plt.ylabel('Visibility (km)')
plt.grid(True)

# Pressure
plt.subplot(3, 2, 6)
plt.plot(weather_data.index, weather_data['Press_kPa'], color='brown', alpha=0.7)
plt.title('Pressure (kPa)')
plt.xlabel('Date/Time')
plt.ylabel('Pressure (kPa)')
plt.grid(True)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %%
weather_data.columns
# Out:
# Index(['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h',
#        'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
weather_data.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
#Create correlation matrices and heatmaps to identify relationships between different weather parameters.
correlation_matrix = weather_data[['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 
                                   'Wind Speed_km/h', 'Visibility_km', 'Press_kPa']].corr()
correlation_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
#Heatmap from the correlation_matrix
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 4. Weather Patterns and Trends
#Analyze and describe any trends or patterns you observe in the data. For instance, how do temperature and humidity vary across different seasons or months?
#Investigate any anomalies or unusual patterns in the data. What might be the reasons for these anomalies?
from scipy import stats
from scipy.stats import pearsonr

pearson_coeff, p_value = stats.pearsonr(weather_data['Temp_C'], weather_data['Rel Hum_%'])
pearson_coeff,p_value
# Out:
# (np.float64(-0.2201819230919853), np.float64(6.59655582189269e-97))

# %% [markdown]
# ANALYSIS
# (1) The pearson coefficient relating temperature and relative humidity returns a -0.22 value indicating a weak realtionship as well as indicating that as the temperature increases, the relative humidity decreases and vice versa.
# (2) From the time series graph above, both the temperature and relative humidity seem to increase steadily during the summer season i.e. from 2012-05 through 2012-09 while the pressure seems to decrease through the same period of 2012-05 through 2012-09
# (3) From the heatmap above, the correlation coefficient relating temperature and dew point temperature is 0.93 indicating a strong relationship. Also, while temperature increases, dew point temperature also increases.
# (4) The correlation coefficient relating visibility and dew point temperature is -0.63 indicating a relatively strong relationship. As the visibility increases, the dew point temperature decreases.
# ANOMALIES IN THE DATA
# (1)The Visibility_km data seems to greatly varying with very extreme outliers with the frequency of data between 20-30km being 5000+, while the remaining close to 3000 or more data being outliers which is about 38% of the total collected data. The anomalies could be a result of misrecording measurements, external conditions such as humidity which can affect measurements, or even incorrect assumptions.

# %% [markdown]
# INSIGHTS
# Here is a summary of everything I have learnt:
# (i)Preparation and cleaning of the data to be analysed
# (ii)Python libraries used for analysing data -pandas, matplotlib, seaborn, plotly- and how to use the libraries for data visualization ie  box plots, scatter plots, histograms, bargraphs etc
# (iii)Measures of central tendency -mean, mode and median- and their importance in data analysis
# (iv)Measures of dispersion -variance, standard deviations, quantiles- and their significance in data analysis
# (v)Data visualization techniques -graphs, charts, plots etc- and how to interpret the resulting patterns
# (vi)Identifying outliers and anomalies in a data set and how to handle them
# (vii)Correlation analysis and understanding relationships between variables

# %% [markdown]
# RECOMMENDATIONS AND CONCLUSIONS
# (i)Investigate outliers and anomalies to better understand their causes and in case the among the causes is data errors, consider correcting them.
# (ii)Perform checks to ensure data consistency across all records, especially for variables like visibility, pressure and wind_speed. Inconsistent records might need correction or exclusion from analysis.
# (iii)Apply clustering techniques to identify different weather patterns or group similar weather days. This can help in identifying typical vs. anomalous weather conditions.
#
# In cocnclusion, the analysis of the weather dataset reveals the presence of significant outliers and anomalies, which could be due to extreme weather events, measurement errors, or data inconsistencies. These outliers and anomalies must be carefully investigated to ensure accurate analysis.Visualizing findings through interactive dashboards will help in monitoring and communicating insights effectively, while further analysis such as clustering and causal analysis can provide deeper insights into the weather patterns.
